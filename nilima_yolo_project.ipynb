# %%
pip install ultralytics opencv-python matplotlib notebook
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import cv2  # keep this, even if not used yet

model = YOLO('yolov8n.pt')




results = model('dog_img.jpg')  # change to your file name if needed
# Show result in its own window
results[0].show()

print(f"Found {len(results[0].boxes)} objects")
# Out:
# image 1/1 c:\Users\ASUS\OneDrive\Desktop\nilima_yolo_project\dog_img.jpg: 640x416 1 dog, 96.7ms
# Speed: 2.8ms preprocess, 96.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
# Found 1 objects

# %%
from ultralytics import YOLO
import cv2

model = YOLO('yolov8n.pt')

cap = cv2.VideoCapture(0)

frame_count = 0
max_frames = 100  # ~3–4 seconds

while frame_count < max_frames:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)
    annotated = results[0].plot()
    cv2.imshow("YOLO Webcam", annotated)

    # if you ever see the window, you can press 'q' to quit early
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    frame_count += 1

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 119.7ms
# Speed: 4.6ms preprocess, 119.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 145.3ms
# Speed: 16.5ms preprocess, 145.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 128.0ms
# Speed: 4.8ms preprocess, 128.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 111.6ms
# Speed: 5.1ms preprocess, 111.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 106.5ms
# Speed: 4.3ms preprocess, 106.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 98.9ms
# Speed: 4.7ms preprocess, 98.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 176.4ms
# Speed: 4.3ms preprocess, 176.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# ...

# %%
# CELL 4 – save a nice detection result

# 1) Run detection again on your image
results = model('dog_img.jpg')   # keep this exactly, same name as in your folder

# 2) Save the annotated result image
results[0].save('yolo_result_nilima.jpg')   # you can change this output name if you want

print("Saved file: yolo_result_nilima.jpg")
# Out:
# image 1/1 c:\Users\ASUS\OneDrive\Desktop\nilima_yolo_project\dog_img.jpg: 640x416 1 dog, 105.7ms
# Speed: 3.6ms preprocess, 105.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
# Saved file: yolo_result_nilima.jpg
